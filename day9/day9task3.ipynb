# %%
import pandas as pd

# %%
usernames = pd.Series(['  Alice ', 'BOB', ' Charlie', 'daisy'])

# %%
usernames
# Out:
# 0      Alice
# 1         BOB
# 2     Charlie
# 3       daisy
# dtype: object

# %%
cleaned = usernames.str.strip().str.lower()
contains_a = cleaned.str.contains('a')

# %%
contains_a
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool
